# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as req

# %%
html="""
<html>
<head>
<meta charset=”utf-8″>
<title>キノコード</title>
</head>
<body>
<h1>情熱、熱意、執念</h1>
</body>
</html>
"""

# %%
html
# Out:
# '\n<html>\n<head>\n<meta charset=”utf-8″>\n<title>キノコード</title>\n</head>\n<body>\n<h1>情熱、熱意、執念</h1>\n</body>\n</html>\n'

# %%
parse_html = BeautifulSoup(html,'html.parser')

# %%
print(parse_html)
# Out:
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>キノコード</title>
# </head>
# <body>
# <h1>情熱、熱意、執念</h1>
# </body>
# </html>

# %%
print(parse_html.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    キノコード
#   </title>
#  </head>
#  <body>
#   <h1>
#    情熱、熱意、執念
#   </h1>
#  </body>
# </html>

# %%
url = "http://kino-code.work/python-scraping/"
response = req.urlopen(url)

# %%
parse_html = BeautifulSoup(response,'html.parser')

# %%
parse_html
# Out:
# <!DOCTYPE html>
# <html lang="ja"><head><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-140862964-1"></script><script>window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments);}gtag('js',new Date());gtag('config','UA-140862964-1');</script><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport"><link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/><link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/><link href="//ajax.googleapis.com" rel="preconnect dns-prefetch"/><link href="//cdnjs.cloudflare.com" rel="preconnect dns-prefetch"/><link href="//pagead2.googlesyndication.com" rel="preconnect dns-prefetch"/><link href="//googleads.g.doubleclick.net" rel="preconnect dns-prefetch"/><link href="//tpc.googlesyndication.com" rel="preconnect dns-prefetch"/><link href="//ad.doubleclick.net" rel="preconnect dns-prefetch"/><link href="//www.gstatic.com" rel="preconnect dns-prefetch"/><link href="//cse.google.com" rel="preconnect dns-prefetch"/><link href="//fonts.gstatic.com" rel="preconnect dns-prefetch"/><link href="//fonts.googleapis.com" rel="preconnect dns-prefetch"/><link href="//cms.quantserve.com" rel="preconnect dns-prefetch"/><link href="//secure.gravatar.com" rel="preconnect dns-prefetch"/><link href="//cdn.syndication.twimg.com" rel="preconnect dns-prefetch"/><link href="//cdn.jsdelivr.net" rel="preconnect dns-prefetch"/><link href="//images-fe.ssl-images-amazon.com" rel="preconnect dns-prefetch"/><link href="//completion.amazon.com" rel="preconnect dns-prefetch"/><link href="//m.media-amazon.com" rel="preconnect dns-prefetch"/><link href="//i.moshimo.com" rel="preconnect dns-prefetch"/><link href="//aml.valuecommerce.com" rel="preconnect dns-prefetch"/><link href="//dalc.valuecommerce.com" rel="preconnect dns-prefetch"/><link href="//dalb.valuecommerce.com" rel="preconnect dns-prefetch"/><title>Python超入門コース(テスト) | KinoCodeWork</title><meta content="noindex,nofollow" name="robots"><meta content="article" property="og:type"/><meta content="Python超入門コース#01 Pythonのコース紹介Python超入門コース#02 Pythonとは？Python超入門コース#03 環境構築 for MacPython超入門コース#04 プログラムの基本構造Python超入門コース#" property="og:description"/><meta content="Python超入門コース(テスト)" property="og:title"/><meta content="https://kino-code.work/python-scraping/" property="og:url"/><meta content="http://localhost:8888/wordpress/wp-content/themes/cocoon-master/screenshot.jpg" property="og:image"/><meta content="KinoCodeWork" property="og:site_name"/><meta content="ja_JP" property="og:locale"/><meta content="2020-12-26T21:43:43+09:00" property="article:published_time"><meta content="2020-12-27T13:26:58+09:00" property="article:modified_time"><meta content="summary_large_image" name="twitter:card"/><meta content="Python超入門コース#01 Pythonのコース紹介Python超入門コース#02 Pythonとは？Python超入門コース#03 環境構築 for MacPython超入門コース#04 プログラムの基本構造Python超入門コース#" property="twitter:description"/><meta content="Python超入門コース(テスト)" property="twitter:title"/><meta content="https://kino-code.work/python-scraping/" property="twitter:url"/><meta content="http://localhost:8888/wordpress/wp-content/themes/cocoon-master/screenshot.jpg" name="twitter:image"/><meta content="kino-code.work" name="twitter:domain"/><meta content="@kino_tsurayasu" name="twitter:creator"/><meta content="@kino_tsurayasu" name="twitter:site"/><link href="//ajax.googleapis.com" rel="dns-prefetch"><link href="//cdnjs.cloudflare.com" rel="dns-prefetch"><link href="//s.w.org" rel="dns-prefetch"><link href="https://kino-code.work/feed/" rel="alternate" title="KinoCodeWork » フィード" type="application/rss+xml"><link href="https://kino-code.work/comments/feed/" rel="alternate" title="KinoCodeWork » コメントフィード" type="application/rss+xml"><script id="jquery-core-js" src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js?ver=1.12.4"></script><script id="jquery-migrate-js" src="https://cdnjs.cloudf ...

# %%
print(parse_html.title)
# Out:
# <title>Python超入門コース(テスト) | KinoCodeWork</title>

# %%
print(parse_html.title.string)
# Out:
# Python超入門コース(テスト) | KinoCodeWork

# %%
print(parse_html.find_all('a'))
# Out:
# [<a class="site-name site-name-text-link" href="https://kino-code.work/" itemprop="url"><span class="site-name-text" itemprop="name about"><img alt="KinoCodeWork" class="site-logo-image header-site-logo-image" height="100" src="http://kino-code.work/wp-content/uploads/2019/07/logo-1.png" width="535"/></span></a>, <a href="https://kino-code.work" itemprop="item"><span class="breadcrumb-caption" itemprop="name">ホーム</span></a>, <a href="https://kino-code.work/course-python01-course-introduction/">Python超入門コース#01 Pythonのコース紹介</a>, <a href="https://kino-code.work/course-python02-what-python/">Python超入門コース#02 Pythonとは？</a>, <a href="https://kino-code.work/course-python03-environment/">Python超入門コース#03 環境構築 for Mac</a>, <a href="https://kino-code.work/course-python04-basic-structure/">Python超入門コース#04 プログラムの基本構造</a>, <a href="https://kino-code.work/course-python05-runtime/">Python超入門コース#05 実行</a>, <a href="https://kino-code.work/course-python06-variable/">Python超入門コース#06 変数</a>, <a href="https://kino-code.work/course-python07-data-type/">Python超入門コース#07 データ型</a>, <a href="https://kino-code.work/coruse-python08-list/">Python超入門コース#08 リスト</a>, <a href="https://kino-code.work/course-python09-operator/">Python超入門コース#09 演算子</a>, <a href="https://kino-code.work/course-python10-conditional-branch/">Python超入門コース#10 条件分岐</a>, <a href="https://kino-code.work/course-python11-repetition/">Python超入門コース#11 反復</a>, <a href="https://kino-code.work/course-python12-function/">Python超入門コース#12 関数</a>, <a href="https://kino-code.work/course-python13-class/">Python超入門コース#13 クラス</a>, <a href="https://kino-code.work/course-python14-practice/">Python超入門コース#14 実践</a>, <a class="author-link" href="https://kino-code.work/author/kino_tsurayasu/"><span class="post-author vcard author" itemprop="editor author creator copyrightHolder" itemscope="" itemtype="https://schema.org/Person"><span class="author-name fn" itemprop="name">キノコード</span></span></a>, <a href="https://kino-code.work/course-go15-practice/">【Go言語 超入門コース】15.実践｜すべて理解できればGoの超入門者から卒業です【プログラミング初心者向け入門講座】</a>, <a href="https://kino-code.work/course-go14-method/">【Go言語 超入門コース】14.メソッド｜Goのメソッドは、他の言語のメソッドとは違っています【プログラミング初心者向け入門講座】</a>, <a href="https://kino-code.work/course-go13-structure/">【Go言語 超入門コース】13.構造体｜構造体ってなんだ？ 異なるデータ型の変数を1つにまとめたもの【プログラミング初心者向け入門講座】</a>, <a href="https://kino-code.work/course-go12-function/">【Go言語 超入門コース】12.関数 ｜関数を料理ロボットに例えて説明しました【プログラミング初心者向け入門講座】</a>, <a href="https://kino-code.work/course-go03-environment-for-windows/">【Go言語 超入門コース】03.環境構築 for Windows｜プログラミングをする準備をしよう！【プログラミング初心者向け入門講座】</a>, <a href="https://kino-code.work/2020/05/">2020年5月<span class="post-count">3</span></a>, <a href="https://kino-code.work/2020/04/">2020年4月<span class="post-count">3</span></a>, <a href="https://kino-code.work/2020/03/">2020年3月<span class="post-count">2</span></a>, <a href="https://kino-code.work/2020/02/">2020年2月<span class="post-count">4</span></a>, <a href="https://kino-code.work/2020/01/">2020年1月<span class="post-count">24</span></a>, <a class="site-name site-name-text-link" href="https://kino-code.work/" itemprop="url"><span class="site-name-text" itemprop="name about"><img alt="KinoCodeWork" class="site-logo-image footer-site-logo-image" src="http://kino-code.work/wp-content/uploads/2019/07/logo-1.png"/></span></a>]

# %%
title_lists=parse_html.find_all('a')

# %%
title_lists[1:10]
# Out:
# [<a href="https://kino-code.work" itemprop="item"><span class="breadcrumb-caption" itemprop="name">ホーム</span></a>,
#  <a href="https://kino-code.work/course-python01-course-introduction/">Python超入門コース#01 Pythonのコース紹介</a>,
#  <a href="https://kino-code.work/course-python02-what-python/">Python超入門コース#02 Pythonとは？</a>,
#  <a href="https://kino-code.work/course-python03-environment/">Python超入門コース#03 環境構築 for Mac</a>,
#  <a href="https://kino-code.work/course-python04-basic-structure/">Python超入門コース#04 プログラムの基本構造</a>,
#  <a href="https://kino-code.work/course-python05-runtime/">Python超入門コース#05 実行</a>,
#  <a href="https://kino-code.work/course-python06-variable/">Python超入門コース#06 変数</a>,
#  <a href="https://kino-code.work/course-python07-data-type/">Python超入門コース#07 データ型</a>,
#  <a href="https://kino-code.work/coruse-python08-list/">Python超入門コース#08 リスト</a>]

# %%
title_lists[10].string
# Out:
# 'Python超入門コース#09 演算子'

# %%
title_lists[10].attrs['href']
# Out:
# 'https://kino-code.work/course-python09-operator/'

# %%
title_list=[]
url_list=[]

for i in title_lists:
    title_list.append(i.string)
    url_list.append(i.attrs['href'])

# %%
title_list
# Out:
# [None,
#  'ホーム',
#  'Python超入門コース#01 Pythonのコース紹介',
#  'Python超入門コース#02 Pythonとは？',
#  'Python超入門コース#03 環境構築 for Mac',
#  'Python超入門コース#04 プログラムの基本構造',
#  'Python超入門コース#05 実行',
#  'Python超入門コース#06 変数',
#  'Python超入門コース#07 データ型',
#  'Python超入門コース#08 リスト',
#  'Python超入門コース#09 演算子',
#  'Python超入門コース#10 条件分岐',
#  'Python超入門コース#11 反復',
#  'Python超入門コース#12 関数',
#  'Python超入門コース#13 クラス',
#  'Python超入門コース#14 実践',
#  'キノコード',
#  '【Go言語 超入門コース】15.実践｜すべて理解できればGoの超入門者から卒業です【プログラミング初心者向け入門講座】',
#  '【Go言語 超入門コース】14.メソッド｜Goのメソッドは、他の言語のメソッドとは違っています【プログラミング初心者向け入門講座】',
#  '【Go言語 超入門コース】13.構造体｜構造体ってなんだ？ 異なるデータ型の変数を1つにまとめたもの【プログラミング初心者向け入門講座】',
#  '【Go言語 超入門コース】12.関数 ｜関数を料理ロボットに例えて説明しました【プログラミング初心者向け入門講座】',
#  '【Go言語 超入門コース】03.環境構築 for Windows｜プログラミングをする準備をしよう！【プログラミング初心者向け入門講座】',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
url_list
# Out:
# ['https://kino-code.work/',
#  'https://kino-code.work',
#  'https://kino-code.work/course-python01-course-introduction/',
#  'https://kino-code.work/course-python02-what-python/',
#  'https://kino-code.work/course-python03-environment/',
#  'https://kino-code.work/course-python04-basic-structure/',
#  'https://kino-code.work/course-python05-runtime/',
#  'https://kino-code.work/course-python06-variable/',
#  'https://kino-code.work/course-python07-data-type/',
#  'https://kino-code.work/coruse-python08-list/',
#  'https://kino-code.work/course-python09-operator/',
#  'https://kino-code.work/course-python10-conditional-branch/',
#  'https://kino-code.work/course-python11-repetition/',
#  'https://kino-code.work/course-python12-function/',
#  'https://kino-code.work/course-python13-class/',
#  'https://kino-code.work/course-python14-practice/',
#  'https://kino-code.work/author/kino_tsurayasu/',
#  'https://kino-code.work/course-go15-practice/',
#  'https://kino-code.work/course-go14-method/',
#  'https://kino-code.work/course-go13-structure/',
#  'https://kino-code.work/course-go12-function/',
#  'https://kino-code.work/course-go03-environment-for-windows/',
#  'https://kino-code.work/2020/05/',
#  'https://kino-code.work/2020/04/',
#  'https://kino-code.work/2020/03/',
#  'https://kino-code.work/2020/02/',
#  'https://kino-code.work/2020/01/',
#  'https://kino-code.work/']

# %%
df_title_url = pd.DataFrame({'Title':title_list, 'URL':url_list})

# %%
df_title_url
# Out:
#                                                 Title  \
# 0                                                None
# 1                                                 ホーム
# 2                        Python超入門コース#01 Pythonのコース紹介
# 3                           Python超入門コース#02 Pythonとは？
# 4                        Python超入門コース#03 環境構築 for Mac
# 5                          Python超入門コース#04 プログラムの基本構造
# 6                                  Python超入門コース#05 実行
# 7                                  Python超入門コース#06 変数
# 8                                Python超入門コース#07 データ型
# 9                                 Python超入門コース#08 リスト
# 10                                Python超入門コース#09 演算子
# 11                               Python超入門コース#10 条件分岐
# 12                                 Python超入門コース#11 反復
# 13                                 Python超入門コース#12 関数
# 14                                Python超入門コース#13 クラス
# 15                                 Python超入門コース#14 実践
# 16                                              キノコード
# 17  【Go言語 超入門コース】15.実践｜すべて理解できればGoの超入門者から卒業です【プログラ...
# 18  【Go言語 超入門コース】14.メソッド｜Goのメソッドは、他の言語のメソッドとは違っていま...
# 19  【Go言語 超入門コース】13.構造体｜構造体ってなんだ？ 異なるデータ型の変数を1つにまと...
# 20  【Go言語 超入門コース】12.関数 ｜関数を料理ロボットに例えて説明しました【プログラミン...
# 21  【Go言語 超入門コース】03.環境構築 for Windows｜プログラミングをする準備を...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
#
#                                                   URL
# 0                             https://kino-code.work/
# 1                              https://kino-code.work
# 2   https://kino-code.work/course-python01-course-...
# 3   https://kino-code.work/course-python02-what-py...
# 4   https://kino-code.work/course-python03-environ...
# 5   https://kino-code.work/course-python04-basic-s...
# 6     https://kino-code.work/course-python05-runtime/
# 7    https://kino-code.work/course-python06-variable/
# 8   https://kino-code.work/course-python07-data-type/
# 9        https://kino-code.work/coruse-python08-list/
# 10   https://kino-code.work/course-python09-operator/
# 11  https://kino-code.work/course-python10-conditi...
# 12  https://kino-code.work/course-python11-repetit...
# 13   https://kino-code.work/course-python12-function/
# 14      https://kino-code.work/course-python13-class/
# 15   https://kino-code.work/course-python14-practice/
# 16      https://kino-code.work/author/kino_tsurayasu/
# 17       https://kino-code.work/course-go15-practice/
# 18         https://kino-code.work/course-go14-method/
# 19      https://kino-code.work/course-go13-structure/
# 20       https://kino-code.work/course-go12-function/
# 21  https://kino-code.work/course-go03-environment...
# 22                    https://kino-code.work/2020/05/
# 23                    https://kino-code.work/2020/04/
# 24                    https://kino-code.work/2020/03/
# 25                    https://kino-code.work/2020/02/
# 26                    https://kino-code.work/2020/01/
# 27                            https://kino-code.work/

# %%
df_notnull = df_title_url.dropna(how='any')

# %%
df_notnull
# Out:
#                                                 Title  \
# 1                                                 ホーム
# 2                        Python超入門コース#01 Pythonのコース紹介
# 3                           Python超入門コース#02 Pythonとは？
# 4                        Python超入門コース#03 環境構築 for Mac
# 5                          Python超入門コース#04 プログラムの基本構造
# 6                                  Python超入門コース#05 実行
# 7                                  Python超入門コース#06 変数
# 8                                Python超入門コース#07 データ型
# 9                                 Python超入門コース#08 リスト
# 10                                Python超入門コース#09 演算子
# 11                               Python超入門コース#10 条件分岐
# 12                                 Python超入門コース#11 反復
# 13                                 Python超入門コース#12 関数
# 14                                Python超入門コース#13 クラス
# 15                                 Python超入門コース#14 実践
# 16                                              キノコード
# 17  【Go言語 超入門コース】15.実践｜すべて理解できればGoの超入門者から卒業です【プログラ...
# 18  【Go言語 超入門コース】14.メソッド｜Goのメソッドは、他の言語のメソッドとは違っていま...
# 19  【Go言語 超入門コース】13.構造体｜構造体ってなんだ？ 異なるデータ型の変数を1つにまと...
# 20  【Go言語 超入門コース】12.関数 ｜関数を料理ロボットに例えて説明しました【プログラミン...
# 21  【Go言語 超入門コース】03.環境構築 for Windows｜プログラミングをする準備を...
#
#                                                   URL
# 1                              https://kino-code.work
# 2   https://kino-code.work/course-python01-course-...
# 3   https://kino-code.work/course-python02-what-py...
# 4   https://kino-code.work/course-python03-environ...
# 5   https://kino-code.work/course-python04-basic-s...
# 6     https://kino-code.work/course-python05-runtime/
# 7    https://kino-code.work/course-python06-variable/
# 8   https://kino-code.work/course-python07-data-type/
# 9        https://kino-code.work/coruse-python08-list/
# 10   https://kino-code.work/course-python09-operator/
# 11  https://kino-code.work/course-python10-conditi...
# 12  https://kino-code.work/course-python11-repetit...
# 13   https://kino-code.work/course-python12-function/
# 14      https://kino-code.work/course-python13-class/
# 15   https://kino-code.work/course-python14-practice/
# 16      https://kino-code.work/author/kino_tsurayasu/
# 17       https://kino-code.work/course-go15-practice/
# 18         https://kino-code.work/course-go14-method/
# 19      https://kino-code.work/course-go13-structure/
# 20       https://kino-code.work/course-go12-function/
# 21  https://kino-code.work/course-go03-environment...

# %%
df_notnull['Title'].str.contains('Python超入門コース')
# Out:
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# Name: Title, dtype: bool

# %%
df_notnull[df_notnull['Title'].str.contains('Python超入門コース')]
# Out:
#                            Title  \
# 2   Python超入門コース#01 Pythonのコース紹介
# 3      Python超入門コース#02 Pythonとは？
# 4   Python超入門コース#03 環境構築 for Mac
# 5     Python超入門コース#04 プログラムの基本構造
# 6             Python超入門コース#05 実行
# 7             Python超入門コース#06 変数
# 8           Python超入門コース#07 データ型
# 9            Python超入門コース#08 リスト
# 10           Python超入門コース#09 演算子
# 11          Python超入門コース#10 条件分岐
# 12            Python超入門コース#11 反復
# 13            Python超入門コース#12 関数
# 14           Python超入門コース#13 クラス
# 15            Python超入門コース#14 実践
#
#                                                   URL
# 2   https://kino-code.work/course-python01-course-...
# 3   https://kino-code.work/course-python02-what-py...
# 4   https://kino-code.work/course-python03-environ...
# 5   https://kino-code.work/course-python04-basic-s...
# 6     https://kino-code.work/course-python05-runtime/
# 7    https://kino-code.work/course-python06-variable/
# 8   https://kino-code.work/course-python07-data-type/
# 9        https://kino-code.work/coruse-python08-list/
# 10   https://kino-code.work/course-python09-operator/
# 11  https://kino-code.work/course-python10-conditi...
# 12  https://kino-code.work/course-python11-repetit...
# 13   https://kino-code.work/course-python12-function/
# 14      https://kino-code.work/course-python13-class/
# 15   https://kino-code.work/course-python14-practice/

# %%
df_contain_python = df_notnull[df_notnull['Title'].str.contains('Python超入門コース')]

# %%
df_contain_python
# Out:
#                            Title  \
# 2   Python超入門コース#01 Pythonのコース紹介
# 3      Python超入門コース#02 Pythonとは？
# 4   Python超入門コース#03 環境構築 for Mac
# 5     Python超入門コース#04 プログラムの基本構造
# 6             Python超入門コース#05 実行
# 7             Python超入門コース#06 変数
# 8           Python超入門コース#07 データ型
# 9            Python超入門コース#08 リスト
# 10           Python超入門コース#09 演算子
# 11          Python超入門コース#10 条件分岐
# 12            Python超入門コース#11 反復
# 13            Python超入門コース#12 関数
# 14           Python超入門コース#13 クラス
# 15            Python超入門コース#14 実践
#
#                                                   URL
# 2   https://kino-code.work/course-python01-course-...
# 3   https://kino-code.work/course-python02-what-py...
# 4   https://kino-code.work/course-python03-environ...
# 5   https://kino-code.work/course-python04-basic-s...
# 6     https://kino-code.work/course-python05-runtime/
# 7    https://kino-code.work/course-python06-variable/
# 8   https://kino-code.work/course-python07-data-type/
# 9        https://kino-code.work/coruse-python08-list/
# 10   https://kino-code.work/course-python09-operator/
# 11  https://kino-code.work/course-python10-conditi...
# 12  https://kino-code.work/course-python11-repetit...
# 13   https://kino-code.work/course-python12-function/
# 14      https://kino-code.work/course-python13-class/
# 15   https://kino-code.work/course-python14-practice/

# %%
df_contain_python.to_csv('scraping_test.csv')
